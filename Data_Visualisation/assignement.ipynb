# %% [markdown]
# save your file in this format : DataViz_20000_NOM2025BDML2.ipynb Dataviz_20250354_MOUISSET--FERRARA2025BDML2.ipynb

# %% [markdown]
# 1) Load & Transform Data
#
#     Read dataset from the given URL :
#
#     path2 = "https://raw.githubusercontent.com/uber-web/kepler.gl-data/master/nyctrips/data.csv"
#
#     df2 = pd.read_csv(path2, delimiter = ',')
#
#     Clean and prepare: parse dates, compute duration, extract time features (hour/day), remove invalid records.
#
# 2) Example : Static Visualizations
#
#     Plot histogram of trip distances.
#
#     Plot trips by hour of the day.
#
# 3) Example : Dynamic Visualizations
#
#     Interactive scatter/map of pickup locations.
#
#     Plot trip duration vs. distance with tooltips.
#
# 3) Explain Figures
#
#     Provide short descriptions highlighting key insights (commuter peaks, hotspots in Manhattan/JFK, short trips dominating, congestion effects).
#
# 4) Storytelling
#
#     Summarize findings to narrate patterns in NYC taxi demand, time, and space usage.
